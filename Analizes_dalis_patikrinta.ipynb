# %%
import numpy as np
import pandas as pd
#from bs4 import BeautifulSoup
import lxml
import html5lib
import seaborn as sns
# import matplotlib as plt

# %% [markdown]
# Nuskaitom pirmą lentelę:

# %%
karsis_eserys1 = pd.read_html('C:/Users/aurel/Pirma_lentele.html')

# %%
karsis_eserys1
# Out:
# [   Vandens telkinio pavadinimas     Kodas          Savivaldybė  \
#  0                       Aisetas  12140251       Utenos r. sav.
#  1                       Almajas  12130086    Ignalinos r. sav.
#  2                         Alnis  12130082       Molėtų r. sav.
#  3             Antakmenių ežeras  10030651        Trakų r. sav.
#  4         Antanavo HE tvenkinys  15050005    Marijampolės sav.
#  5                      Apvardai  50030211    Ignalinos r. sav.
#  6                        Arinas  12140420       Molėtų r. sav.
#  7                       Asalnai  12130004    Ignalinos r. sav.
#  8                        Asavas  12230015       Zarasų r. sav.
#  9                        Atesys  10040584      Alytaus r. sav.
#  10    Aukštadvario HE tvenkinys  10050212        Trakų r. sav.
#  11                       Aviris  10030319     Druskininkų sav.
#  12   Baltosios Ančios tvenkinys  10050030      Lazdijų r. sav.
#  13                     Baluošai  12130412   Švenčionių r. sav.
# ...

# %%
karsis_eserys1[0]
# Out:
#    Vandens telkinio pavadinimas     Kodas          Savivaldybė  \
# 0                       Aisetas  12140251       Utenos r. sav.
# 1                       Almajas  12130086    Ignalinos r. sav.
# 2                         Alnis  12130082       Molėtų r. sav.
# 3             Antakmenių ežeras  10030651        Trakų r. sav.
# 4         Antanavo HE tvenkinys  15050005    Marijampolės sav.
# 5                      Apvardai  50030211    Ignalinos r. sav.
# 6                        Arinas  12140420       Molėtų r. sav.
# 7                       Asalnai  12130004    Ignalinos r. sav.
# 8                        Asavas  12230015       Zarasų r. sav.
# 9                        Atesys  10040584      Alytaus r. sav.
# 10    Aukštadvario HE tvenkinys  10050212        Trakų r. sav.
# 11                       Aviris  10030319     Druskininkų sav.
# 12   Baltosios Ančios tvenkinys  10050030      Lazdijų r. sav.
# 13                     Baluošai  12130412   Švenčionių r. sav.
# ...

# %%
zuvys1 = karsis_eserys1[0]
zuvys1.to_csv('karsis_eserys1.csv', index=False)

# %% [markdown]
# Nuskaitom antrą lentelę:

# %%
karsis_eserys2 = pd.read_html('C:/Users/aurel/Antra_lentele.html')

# %%
karsis_eserys2
# Out:
# [   Vandens telkinio pavadinimas     Kodas         Savivaldybė  \
#  0                    Utenykštis  12130111      Utenos r. sav.
#  1                      Vajuonis  12130127  Švenčionių r. sav.
#  2                    Vidinkstas  12241566      Utenos r. sav.
#  3                        Vievis  12030300      Elektrėnų sav.
#  4                     Viešintas  41030053    Anykščių r. sav.
#  5                        Vilkas  10030227    Druskininkų sav.
#  6                      Vilkinys  10030253     Lazdijų r. sav.
#  7                      Virintai  12241640      Molėtų r. sav.
#  8                        Zapsys  10030110     Lazdijų r. sav.
#  9                       Zarasas  50030302      Zarasų r. sav.
#  10                      Čičirys  50030474      Zarasų r. sav.
#  11                    Šlavantas  10030010     Lazdijų r. sav.
#
#      Žuvų išteklių būklės indeksasi  Biomasė (kg)i  Gausumas (vnt.)i  \
#  0                             0.21          1.627                53
# ...

# %%
karsis_eserys2[0]
# Out:
#    Vandens telkinio pavadinimas     Kodas         Savivaldybė  \
# 0                    Utenykštis  12130111      Utenos r. sav.
# 1                      Vajuonis  12130127  Švenčionių r. sav.
# 2                    Vidinkstas  12241566      Utenos r. sav.
# 3                        Vievis  12030300      Elektrėnų sav.
# 4                     Viešintas  41030053    Anykščių r. sav.
# 5                        Vilkas  10030227    Druskininkų sav.
# 6                      Vilkinys  10030253     Lazdijų r. sav.
# 7                      Virintai  12241640      Molėtų r. sav.
# 8                        Zapsys  10030110     Lazdijų r. sav.
# 9                       Zarasas  50030302      Zarasų r. sav.
# 10                      Čičirys  50030474      Zarasų r. sav.
# 11                    Šlavantas  10030010     Lazdijų r. sav.
#
#     Žuvų išteklių būklės indeksasi  Biomasė (kg)i  Gausumas (vnt.)i  \
# 0                             0.21          1.627                53
# ...

# %%
zuvys2 = karsis_eserys2[0]
zuvys2.to_csv('karsis_eserys2.csv', index=False)

# %% [markdown]
# Lentelių sujungimas:

# %%
zuvys_kartu = pd.concat([zuvys1, zuvys2], sort=False)

# %%
zuvys_kartu.head(62)
# Out:
#    Vandens telkinio pavadinimas     Kodas        Savivaldybė  \
# 0                       Aisetas  12140251     Utenos r. sav.
# 1                       Almajas  12130086  Ignalinos r. sav.
# 2                         Alnis  12130082     Molėtų r. sav.
# 3             Antakmenių ežeras  10030651      Trakų r. sav.
# 4         Antanavo HE tvenkinys  15050005  Marijampolės sav.
# ..                          ...       ...                ...
# 7                      Virintai  12241640     Molėtų r. sav.
# 8                        Zapsys  10030110    Lazdijų r. sav.
# 9                       Zarasas  50030302     Zarasų r. sav.
# 10                      Čičirys  50030474     Zarasų r. sav.
# 11                    Šlavantas  10030010    Lazdijų r. sav.
#
#     Žuvų išteklių būklės indeksasi  Biomasė (kg)i  Gausumas (vnt.)i  \
# 0                             0.49          1.740                38
# 1                             0.47          1.227                27
# ...

# %% [markdown]
# Patikrinama kokie lentelės stulpelių pavadinimai:

# %%
zuvys_kartu.columns.values.tolist()
# Out:
# ['Vandens telkinio pavadinimas',
#  'Kodas',
#  'Savivaldybė',
#  'Žuvų išteklių būklės indeksasi',
#  'Biomasė (kg)i',
#  'Gausumas (vnt.)i',
#  'Plėšrių žuvų gausumas (%)i',
#  'Plėšrių žuvų biomasė (%)i',
#  'Ešerys (Gausumas)',
#  'Karšis (Gausumas)',
#  'Unnamed: 10']

# %% [markdown]
# Norimų stulpelių pervadinimas:

# %%
zuvys_kartu.rename(
    columns={"Žuvų išteklių būklės indeksasi": "Žuvų būklės indeksas",
    "Biomasė (kg)i": "Biomasė(kg)",
    "Gausumas (vnt.)i": "Gausumas(vnt)",
    "Plėšrių žuvų gausumas (%)i": "Plėšrių žuvų gausumas(%)",
    "Plėšrių žuvų biomasė (%)i": "Plėšrių žuvų biomasė(%)"},
    inplace=True,)

# %%
zuvys_kartu
# Out:
#    Vandens telkinio pavadinimas     Kodas        Savivaldybė  \
# 0                       Aisetas  12140251     Utenos r. sav.
# 1                       Almajas  12130086  Ignalinos r. sav.
# 2                         Alnis  12130082     Molėtų r. sav.
# 3             Antakmenių ežeras  10030651      Trakų r. sav.
# 4         Antanavo HE tvenkinys  15050005  Marijampolės sav.
# ..                          ...       ...                ...
# 7                      Virintai  12241640     Molėtų r. sav.
# 8                        Zapsys  10030110    Lazdijų r. sav.
# 9                       Zarasas  50030302     Zarasų r. sav.
# 10                      Čičirys  50030474     Zarasų r. sav.
# 11                    Šlavantas  10030010    Lazdijų r. sav.
#
#     Žuvų būklės indeksas  Biomasė(kg)  Gausumas(vnt)  \
# 0                   0.49        1.740             38
# 1                   0.47        1.227             27
# 2                   0.57        3.798             42
# ...

# %% [markdown]
# Nereikalingo paskutinio stulpelio pašalinimas:

# %%
zuvys_kartu.drop(columns=['Unnamed: 10'], inplace=True)

# %%
zuvys_kartu.head(10)
# Out:
#   Vandens telkinio pavadinimas     Kodas        Savivaldybė  \
# 0                      Aisetas  12140251     Utenos r. sav.
# 1                      Almajas  12130086  Ignalinos r. sav.
# 2                        Alnis  12130082     Molėtų r. sav.
# 3            Antakmenių ežeras  10030651      Trakų r. sav.
# 4        Antanavo HE tvenkinys  15050005  Marijampolės sav.
# 5                     Apvardai  50030211  Ignalinos r. sav.
# 6                       Arinas  12140420     Molėtų r. sav.
# 7                      Asalnai  12130004  Ignalinos r. sav.
# 8                       Asavas  12230015     Zarasų r. sav.
# 9                       Atesys  10040584    Alytaus r. sav.
#
#    Žuvų būklės indeksas  Biomasė(kg)  Gausumas(vnt)  Plėšrių žuvų gausumas(%)  \
# 0                  0.49        1.740             38                      1.61
# 1                  0.47        1.227             27                      2.17
# ...

# %% [markdown]
# Indekso pakeitimas, kad elementų skaičiavimas prasidėtų nuo 1:

# %%
zuvys_kartu['index'] = list(range(1, 63))
zuvys_kartu.set_index('index', inplace=True)
zuvys_kartu.head(10)
# Out:
#       Vandens telkinio pavadinimas     Kodas        Savivaldybė  \
# index
# 1                          Aisetas  12140251     Utenos r. sav.
# 2                          Almajas  12130086  Ignalinos r. sav.
# 3                            Alnis  12130082     Molėtų r. sav.
# 4                Antakmenių ežeras  10030651      Trakų r. sav.
# 5            Antanavo HE tvenkinys  15050005  Marijampolės sav.
# 6                         Apvardai  50030211  Ignalinos r. sav.
# 7                           Arinas  12140420     Molėtų r. sav.
# 8                          Asalnai  12130004  Ignalinos r. sav.
# 9                           Asavas  12230015     Zarasų r. sav.
# 10                          Atesys  10040584    Alytaus r. sav.
#
#        Žuvų būklės indeksas  Biomasė(kg)  Gausumas(vnt)  \
# index
# 1                      0.49        1.740             38
# 2                      0.47        1.227             27
# 3                      0.57        3.798             42
# ...

# %% [markdown]
# Tikrinam ar yra nulio reikšmių:

# %%
zuvys_kartu.isnull().sum()
# Out:
# Vandens telkinio pavadinimas    0
# Kodas                           0
# Savivaldybė                     0
# Žuvų būklės indeksas            0
# Biomasė(kg)                     0
# Gausumas(vnt)                   0
# Plėšrių žuvų gausumas(%)        0
# Plėšrių žuvų biomasė(%)         0
# Ešerys (Gausumas)               0
# Karšis (Gausumas)               0
# dtype: int64

# %% [markdown]
# Tikrinam ar nėra NaN reikšmių:

# %%
zuvys_kartu.isna().sum()
# Out:
# Vandens telkinio pavadinimas    0
# Kodas                           0
# Savivaldybė                     0
# Žuvų būklės indeksas            0
# Biomasė(kg)                     0
# Gausumas(vnt)                   0
# Plėšrių žuvų gausumas(%)        0
# Plėšrių žuvų biomasė(%)         0
# Ešerys (Gausumas)               0
# Karšis (Gausumas)               0
# dtype: int64

# %% [markdown]
# Patikrinimas ar nėra besidubliuojančių reikšmių:

# %%
zuvys_kartu.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Kadangi nėra tuščių, nulinių ar vienodų reikšmių, keičiu "-" reikšmes į "0", kad galėčiau naudoti stulpelius skaičiavimams:

# %%
zuvys_kartu = zuvys_kartu.replace(['-'], '0')
zuvys_kartu.head(10)
# Out:
#       Vandens telkinio pavadinimas     Kodas        Savivaldybė  \
# index
# 1                          Aisetas  12140251     Utenos r. sav.
# 2                          Almajas  12130086  Ignalinos r. sav.
# 3                            Alnis  12130082     Molėtų r. sav.
# 4                Antakmenių ežeras  10030651      Trakų r. sav.
# 5            Antanavo HE tvenkinys  15050005  Marijampolės sav.
# 6                         Apvardai  50030211  Ignalinos r. sav.
# 7                           Arinas  12140420     Molėtų r. sav.
# 8                          Asalnai  12130004  Ignalinos r. sav.
# 9                           Asavas  12230015     Zarasų r. sav.
# 10                          Atesys  10040584    Alytaus r. sav.
#
#        Žuvų būklės indeksas  Biomasė(kg)  Gausumas(vnt)  \
# index
# 1                      0.49        1.740             38
# 2                      0.47        1.227             27
# 3                      0.57        3.798             42
# ...

# %% [markdown]
# Noriu patikrinti ar nėra nelogiško skaičiaus(Marijampolės savivaldybė), todėl rūšiuoju Biomasės stulpelį, nuo didžiausio:

# %%
zuvys_kartu.sort_values(by='Biomasė(kg)', ascending=False)
# Out:
#       Vandens telkinio pavadinimas     Kodas         Savivaldybė  \
# index
# 5            Antanavo HE tvenkinys  15050005   Marijampolės sav.
# 22               Ginkūnų tvenkinys  41050046     Šiaulių r. sav.
# 44                       Spindžius  10030865       Trakų r. sav.
# 14                        Baluošai  12130412  Švenčionių r. sav.
# 29             Labūnavos tvenkinys  13050221    Kėdainių r. sav.
# ...                            ...       ...                 ...
# 28                       Kretuonas  12130044  Švenčionių r. sav.
# 23                           Ilgai  10031016       Trakų r. sav.
# 46                        Sągardas  50030006   Ignalinos r. sav.
# 59                          Zapsys  10030110     Lazdijų r. sav.
# 2                          Almajas  12130086   Ignalinos r. sav.
#
#        Žuvų būklės indeksas  Biomasė(kg)  Gausumas(vnt)  \
# index
# 5                      0.63     8990.000            107
# ...

# %% [markdown]
# Patikrinus, randu, kad tikriausia įsivėlė klaida.
# Todėl keičiu skaičių atsižvelgus į kitus esančius:

# %%
zuvys_kartu.iat[4, 4] = 8.990
zuvys_kartu.head(5)
# Out:
#       Vandens telkinio pavadinimas     Kodas        Savivaldybė  \
# index
# 1                          Aisetas  12140251     Utenos r. sav.
# 2                          Almajas  12130086  Ignalinos r. sav.
# 3                            Alnis  12130082     Molėtų r. sav.
# 4                Antakmenių ežeras  10030651      Trakų r. sav.
# 5            Antanavo HE tvenkinys  15050005  Marijampolės sav.
#
#        Žuvų būklės indeksas  Biomasė(kg)  Gausumas(vnt)  \
# index
# 1                      0.49        1.740             38
# 2                      0.47        1.227             27
# 3                      0.57        3.798             42
# 4                      1.00        5.435            118
# 5                      0.63        8.990            107
#
#        Plėšrių žuvų gausumas(%)  Plėšrių žuvų biomasė(%) Ešerys (Gausumas)  \
# index
# 1                          1.61                    16.45                 0
# ...

# %% [markdown]
# Paskaičiuojami visų stulpelių vidurkiai, didžiausios ir mažiausios reikšmės ir panašiai:

# %%
zuvys_kartu.describe()
# Out:
#               Kodas  Žuvų būklės indeksas  Biomasė(kg)  Gausumas(vnt)  \
# count  6.200000e+01             62.000000    62.000000      62.000000
# mean   1.839918e+07              0.568548     4.272548      70.193548
# std    1.307509e+07              0.224812     2.364010      38.749654
# min    1.003001e+07              0.210000     1.227000      22.000000
# 25%    1.205523e+07              0.430000     2.479000      39.250000
# 50%    1.213533e+07              0.505000     3.898000      61.500000
# 75%    1.455006e+07              0.685000     5.235000      90.500000
# max    5.005000e+07              1.000000    10.671000     224.000000
#
#        Plėšrių žuvų gausumas(%)  Plėšrių žuvų biomasė(%)
# count                 62.000000                62.000000
# mean                   1.718387                10.815484
# std                    1.235492                10.189557
# min                    0.100000                 0.000000
# ...

# %% [markdown]
# Patikrinu blogiausios būklės telkinio pagal būklės indekso reikšmę informaciją:

# %%
zuvys_kartu.loc[zuvys_kartu['Žuvų būklės indeksas'].idxmin()]
# Out:
# Vandens telkinio pavadinimas        Utenykštis
# Kodas                                 12130111
# Savivaldybė                     Utenos r. sav.
# Žuvų būklės indeksas                      0.21
# Biomasė(kg)                              1.627
# Gausumas(vnt)                               53
# Plėšrių žuvų gausumas(%)                   0.1
# Plėšrių žuvų biomasė(%)                   3.78
# Ešerys (Gausumas)                            0
# Karšis (Gausumas)                            0
# Name: 51, dtype: object

# %% [markdown]
# Patikrinu, kiek yra kokių būklės indekso reikšmių, rūšiuojant nuo didžiausio skaičiaus(1):

# %%
zuvys_kartu['Žuvų būklės indeksas'].value_counts(sort=True)
# Out:
# 1.00    9
# 0.44    3
# 0.45    3
# 0.28    2
# 0.52    2
# 0.50    2
# 0.43    2
# 0.65    2
# 0.48    2
# 0.31    2
# 0.49    2
# 0.70    2
# 0.55    2
# 0.63    2
# 0.30    2
# 0.42    2
# 0.76    1
# 0.26    1
# 0.67    1
# 0.35    1
# 0.40    1
# 0.21    1
# 0.58    1
# 0.59    1
# 0.57    1
# 0.64    1
# 0.77    1
# 0.29    1
# 0.33    1
# 0.69    1
# 0.46    1
# 0.47    1
# 0.74    1
# 0.51    1
# 0.80    1
# 0.37    1
# 0.60    1
# Name: Žuvų būklės indeksas, dtype: int64

# %% [markdown]
# Kadangi matau, kad net 9 telkiniai turi max vertinimą, tai .idxmax nepadės, nes rodys tik vieną(pirmą tinkamą) vandens telkinį.
# Todėl ieškomi ir atvaizduojami visi variantai su max indeksu:

# %%
zuvys_kartu.loc[zuvys_kartu['Žuvų būklės indeksas']==zuvys_kartu['Žuvų būklės indeksas'].max()].T
# Out:
# index                                        4                 12  \
# Vandens telkinio pavadinimas  Antakmenių ežeras            Aviris
# Kodas                                  10030651          10030319
# Savivaldybė                       Trakų r. sav.  Druskininkų sav.
# Žuvų būklės indeksas                        1.0               1.0
# Biomasė(kg)                               5.435             3.953
# Gausumas(vnt)                               118                69
# Plėšrių žuvų gausumas(%)                    1.0               1.0
# Plėšrių žuvų biomasė(%)                     1.0               1.0
# Ešerys (Gausumas)                             0                 0
# Karšis (Gausumas)                             0                 0
#
# index                                       25              40  \
# Vandens telkinio pavadinimas  Juodieji Lakajai        Pravalas
# Kodas                                 12130250        12141212
# ...

# %% [markdown]
# Taip pat patikrinama kiek telkinių ir kokioje savivaldybėje yra geriausios būklės(kai indeksas 1):

# %%
tvarkom = zuvys_kartu.groupby(['Žuvų būklės indeksas'])['Savivaldybė'].value_counts()[1]
tvarkom
# Out:
# Savivaldybė
# Lazdijų r. sav.      3
# Molėtų r. sav.       2
# Druskininkų sav.     1
# Ignalinos r. sav.    1
# Trakų r. sav.        1
# Utenos r. sav.       1
# Name: Savivaldybė, dtype: int64

# %% [markdown]
# Grupuojant galima sužinoti kiek telkinių kokioje savivaldybėje buvo ištirta iš viso:

# %%
vietove = zuvys_kartu.groupby('Savivaldybė')
vietove

# %%
kokiu_daugiausia_vietu = vietove.count()
kokiu_daugiausia_vietu.head(24)
# Out:
#                      Vandens telkinio pavadinimas  Kodas  \
# Savivaldybė
# Akmenės r. sav.                                 1      1
# Alytaus r. sav.                                 2      2
# Anykščių r. sav.                                1      1
# Druskininkų sav.                                2      2
# Elektrėnų sav.                                  1      1
# Ignalinos r. sav.                               9      9
# Kaišiadorių r. sav.                             1      1
# Kretingos r. sav.                               1      1
# Kėdainių r. sav.                                2      2
# Lazdijų r. sav.                                 6      6
# Marijampolės sav.                               1      1
# Molėtų r. sav.                                  9      9
# Pakruojo r. sav.                                1      1
# Rokiškio r. sav.                                1      1
# Telšių r. sav.                                  3      3
# ...

# %% [markdown]
# Kadangi norėsiu palyginti kokią dalį plėšri žuvis sudaro palyginus su visu sugautų žuvų kiekiu,
# tai plėšrių žuvų biomasę procentais reikia paversti į kilogramus:

# %%
biomase_kg = 100
zuvys_kartu['Plėšrios(kg)'] = (zuvys_kartu['Biomasė(kg)'] * zuvys_kartu['Plėšrių žuvų biomasė(%)'] / biomase_kg).round(3)
zuvys_kartu.head(10)
# Out:
#       Vandens telkinio pavadinimas     Kodas        Savivaldybė  \
# index
# 1                          Aisetas  12140251     Utenos r. sav.
# 2                          Almajas  12130086  Ignalinos r. sav.
# 3                            Alnis  12130082     Molėtų r. sav.
# 4                Antakmenių ežeras  10030651      Trakų r. sav.
# 5            Antanavo HE tvenkinys  15050005  Marijampolės sav.
# 6                         Apvardai  50030211  Ignalinos r. sav.
# 7                           Arinas  12140420     Molėtų r. sav.
# 8                          Asalnai  12130004  Ignalinos r. sav.
# 9                           Asavas  12230015     Zarasų r. sav.
# 10                          Atesys  10040584    Alytaus r. sav.
#
#        Žuvų būklės indeksas  Biomasė(kg)  Gausumas(vnt)  \
# index
# 1                      0.49        1.740             38
# 2                      0.47        1.227             27
# 3                      0.57        3.798             42
# ...

# %% [markdown]
# Sukuriu .csv lentelę su jau sutvarkytais duomenimis, taip pat sukuriu sukuriu ryšį su duomenų baze ir į ja įkeliu lentelę:

# %%
from sqlalchemy import create_engine

# %%
zuvys_kartu.to_csv('zuvys.csv', index=False)

engine = create_engine('sqlite:///zuveles.db')
zuvys_kartu.to_sql('zuvys', con=engine, index=False)
# Out:
# 62

# %% [markdown]
# Teigiamas koreliacijos koeficientas rodo, kad vienam kintamajam didėjant, didėja ir kitas kintamasis. Neigiama koreliacija rodo, kad vienam didėjant, kitas kintamasis mažėja. Kuo reikšmė arčiau –1 arba 1, tuo priklausomybė tarp kintamųjų yra stipresnė.

# %%
koreliacija = zuvys_kartu.corr()
koreliacija
# Out:
# C:\Users\aurel\AppData\Local\Temp\ipykernel_8280\1514307060.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   koreliacija = zuvys_kartu.corr()
#                              Kodas  Žuvų būklės indeksas  Biomasė(kg)  \
# Kodas                     1.000000             -0.068367     0.124120
# Žuvų būklės indeksas     -0.068367              1.000000     0.125274
# Biomasė(kg)               0.124120              0.125274     1.000000
# Gausumas(vnt)            -0.035638             -0.239111     0.560562
# Plėšrių žuvų gausumas(%) -0.141596              0.307411     0.187442
# Plėšrių žuvų biomasė(%)  -0.198487             -0.035667     0.046200
# Plėšrios(kg)             -0.043719              0.054116     0.539083
#
#                           Gausumas(vnt)  Plėšrių žuvų gausumas(%)  \
# ...

# %% [markdown]
# Koreliacijos žemėlapis:

# %%
sns.heatmap(koreliacija, annot=True)
# Out:
# <Axes: >

# %%
sns.lineplot(data=zuvys_kartu, x="Plėšrios(kg)", y="Biomasė(kg)")
# galiu nurodyt legendoj ka noriu kad butu, pvz: hue="Savivaldybė"
# Out:
# <Axes: xlabel='Plėšrios(kg)', ylabel='Biomasė(kg)'>
