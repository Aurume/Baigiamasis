# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import lxml
import html5lib
#import IPython.core.display
import sqlalchemy

# %%
karsis_eserys1 = pd.read_html('C:/Users/aurel/Pirma_lentele.html')
#pd.read_html(str(table), displayed_only=False)[0]

# %%
# import re
# import requests

# html_source = requests.get('https://biip.lt/moduliai/zuvu-istekliu-tyrimai/').text
# html_source = re.sub(r'<.*?>', lambda g: g.group(0).upper(), html_source)

# dataframe = pd.read_html(html_source)
# print(dataframe)

# %%
karsis_eserys1
# Out:
# [   Vandens telkinio pavadinimas     Kodas          Savivaldybė  \
#  0                       Aisetas  12140251       Utenos r. sav.
#  1                       Almajas  12130086    Ignalinos r. sav.
#  2                         Alnis  12130082       Molėtų r. sav.
#  3             Antakmenių ežeras  10030651        Trakų r. sav.
#  4         Antanavo HE tvenkinys  15050005    Marijampolės sav.
#  5                      Apvardai  50030211    Ignalinos r. sav.
#  6                        Arinas  12140420       Molėtų r. sav.
#  7                       Asalnai  12130004    Ignalinos r. sav.
#  8                        Asavas  12230015       Zarasų r. sav.
#  9                        Atesys  10040584      Alytaus r. sav.
#  10    Aukštadvario HE tvenkinys  10050212        Trakų r. sav.
#  11                       Aviris  10030319     Druskininkų sav.
#  12   Baltosios Ančios tvenkinys  10050030      Lazdijų r. sav.
#  13                     Baluošai  12130412   Švenčionių r. sav.
# ...

# %%
karsis_eserys1[0]
# Out:
#    Vandens telkinio pavadinimas     Kodas          Savivaldybė  \
# 0                       Aisetas  12140251       Utenos r. sav.
# 1                       Almajas  12130086    Ignalinos r. sav.
# 2                         Alnis  12130082       Molėtų r. sav.
# 3             Antakmenių ežeras  10030651        Trakų r. sav.
# 4         Antanavo HE tvenkinys  15050005    Marijampolės sav.
# 5                      Apvardai  50030211    Ignalinos r. sav.
# 6                        Arinas  12140420       Molėtų r. sav.
# 7                       Asalnai  12130004    Ignalinos r. sav.
# 8                        Asavas  12230015       Zarasų r. sav.
# 9                        Atesys  10040584      Alytaus r. sav.
# 10    Aukštadvario HE tvenkinys  10050212        Trakų r. sav.
# 11                       Aviris  10030319     Druskininkų sav.
# 12   Baltosios Ančios tvenkinys  10050030      Lazdijų r. sav.
# 13                     Baluošai  12130412   Švenčionių r. sav.
# ...

# %%
zuvys1 = karsis_eserys1[0]

# %%
# zuvys1.info - parodo lygiai ta pati kaip pirma istrauksta lentele

# %%
zuvys1.to_csv('karsis_eserys1.csv', index=False)

# %%
karsis_eserys2 = pd.read_html('C:/Users/aurel/Antra_lentele.html')

# %%
karsis_eserys2
# Out:
# [   Vandens telkinio pavadinimas     Kodas         Savivaldybė  \
#  0                    Utenykštis  12130111      Utenos r. sav.
#  1                      Vajuonis  12130127  Švenčionių r. sav.
#  2                    Vidinkstas  12241566      Utenos r. sav.
#  3                        Vievis  12030300      Elektrėnų sav.
#  4                     Viešintas  41030053    Anykščių r. sav.
#  5                        Vilkas  10030227    Druskininkų sav.
#  6                      Vilkinys  10030253     Lazdijų r. sav.
#  7                      Virintai  12241640      Molėtų r. sav.
#  8                        Zapsys  10030110     Lazdijų r. sav.
#  9                       Zarasas  50030302      Zarasų r. sav.
#  10                      Čičirys  50030474      Zarasų r. sav.
#  11                    Šlavantas  10030010     Lazdijų r. sav.
#
#      Žuvų išteklių būklės indeksasi  Biomasė (kg)i  Gausumas (vnt.)i  \
#  0                             0.21          1.627                53
# ...

# %%
karsis_eserys2[0]
# Out:
#    Vandens telkinio pavadinimas     Kodas         Savivaldybė  \
# 0                    Utenykštis  12130111      Utenos r. sav.
# 1                      Vajuonis  12130127  Švenčionių r. sav.
# 2                    Vidinkstas  12241566      Utenos r. sav.
# 3                        Vievis  12030300      Elektrėnų sav.
# 4                     Viešintas  41030053    Anykščių r. sav.
# 5                        Vilkas  10030227    Druskininkų sav.
# 6                      Vilkinys  10030253     Lazdijų r. sav.
# 7                      Virintai  12241640      Molėtų r. sav.
# 8                        Zapsys  10030110     Lazdijų r. sav.
# 9                       Zarasas  50030302      Zarasų r. sav.
# 10                      Čičirys  50030474      Zarasų r. sav.
# 11                    Šlavantas  10030010     Lazdijų r. sav.
#
#     Žuvų išteklių būklės indeksasi  Biomasė (kg)i  Gausumas (vnt.)i  \
# 0                             0.21          1.627                53
# ...

# %%
zuvys2 = karsis_eserys2[0]

# %%
zuvys2.to_csv('karsis_eserys2.csv', index=False)

# %%
# zuvys2.info

# %%
# jungiam lenteles, pasitikslinti del indekso
zuvys_kartu = pd.concat([zuvys1, zuvys2], sort=False)

# %%
#zuvys_kartu['indeksas'] = list(range(1, 62))
# data['#'] = list(range(1, 51))

# %%
zuvys_kartu.head(12)
# Out:
#    Vandens telkinio pavadinimas     Kodas        Savivaldybė  \
# 0                       Aisetas  12140251     Utenos r. sav.
# 1                       Almajas  12130086  Ignalinos r. sav.
# 2                         Alnis  12130082     Molėtų r. sav.
# 3             Antakmenių ežeras  10030651      Trakų r. sav.
# 4         Antanavo HE tvenkinys  15050005  Marijampolės sav.
# 5                      Apvardai  50030211  Ignalinos r. sav.
# 6                        Arinas  12140420     Molėtų r. sav.
# 7                       Asalnai  12130004  Ignalinos r. sav.
# 8                        Asavas  12230015     Zarasų r. sav.
# 9                        Atesys  10040584    Alytaus r. sav.
# 10    Aukštadvario HE tvenkinys  10050212      Trakų r. sav.
# 11                       Aviris  10030319   Druskininkų sav.
#
#     Žuvų išteklių būklės indeksasi  Biomasė (kg)i  Gausumas (vnt.)i  \
# 0                             0.49          1.740                38
# ...

# %%
zuvys_kartu.columns.values.tolist()
# Out:
# ['Vandens telkinio pavadinimas',
#  'Kodas',
#  'Savivaldybė',
#  'Žuvų išteklių būklės indeksasi',
#  'Biomasė (kg)i',
#  'Gausumas (vnt.)i',
#  'Plėšrių žuvų gausumas (%)i',
#  'Plėšrių žuvų biomasė (%)i',
#  'Ešerys (Gausumas)',
#  'Karšis (Gausumas)',
#  'Unnamed: 10']

# %%
zuvys_kartu.drop(columns=['Unnamed: 10'], inplace=True)

# %%
zuvys_kartu
# Out:
#    Vandens telkinio pavadinimas     Kodas        Savivaldybė  \
# 0                       Aisetas  12140251     Utenos r. sav.
# 1                       Almajas  12130086  Ignalinos r. sav.
# 2                         Alnis  12130082     Molėtų r. sav.
# 3             Antakmenių ežeras  10030651      Trakų r. sav.
# 4         Antanavo HE tvenkinys  15050005  Marijampolės sav.
# ..                          ...       ...                ...
# 7                      Virintai  12241640     Molėtų r. sav.
# 8                        Zapsys  10030110    Lazdijų r. sav.
# 9                       Zarasas  50030302     Zarasų r. sav.
# 10                      Čičirys  50030474     Zarasų r. sav.
# 11                    Šlavantas  10030010    Lazdijų r. sav.
#
#     Žuvų išteklių būklės indeksasi  Biomasė (kg)i  Gausumas (vnt.)i  \
# 0                             0.49          1.740                38
# 1                             0.47          1.227                27
# ...

# %%
#zuvys_kartu.reset_index(inplace=True)

# %%
#zuvys_kartu.head(62)

# %%
#padarom indeksa nuo 1, o ne nulio.
zuvys_kartu['index'] = list(range(1, 63))

# %%
zuvys_kartu.set_index('index', inplace=True)

# %%
zuvys_kartu.head(60)
# Out:
#       Vandens telkinio pavadinimas     Kodas          Savivaldybė  \
# index
# 1                          Aisetas  12140251       Utenos r. sav.
# 2                          Almajas  12130086    Ignalinos r. sav.
# 3                            Alnis  12130082       Molėtų r. sav.
# 4                Antakmenių ežeras  10030651        Trakų r. sav.
# 5            Antanavo HE tvenkinys  15050005    Marijampolės sav.
# 6                         Apvardai  50030211    Ignalinos r. sav.
# 7                           Arinas  12140420       Molėtų r. sav.
# 8                          Asalnai  12130004    Ignalinos r. sav.
# 9                           Asavas  12230015       Zarasų r. sav.
# 10                          Atesys  10040584      Alytaus r. sav.
# 11       Aukštadvario HE tvenkinys  10050212        Trakų r. sav.
# 12                          Aviris  10030319     Druskininkų sav.
# 13      Baltosios Ančios tvenkinys  10050030      Lazdijų r. sav.
# ...

# %%
zuvys_kartu.to_csv('sujungtos_zuvys.csv', index=False)

# %%
zuvys_kartu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62 entries, 1 to 62
# Data columns (total 10 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Vandens telkinio pavadinimas    62 non-null     object
#  1   Kodas                           62 non-null     int64
#  2   Savivaldybė                     62 non-null     object
#  3   Žuvų išteklių būklės indeksasi  62 non-null     float64
#  4   Biomasė (kg)i                   62 non-null     float64
#  5   Gausumas (vnt.)i                62 non-null     int64
#  6   Plėšrių žuvų gausumas (%)i      62 non-null     float64
#  7   Plėšrių žuvų biomasė (%)i       62 non-null     float64
#  8   Ešerys (Gausumas)               62 non-null     object
#  9   Karšis (Gausumas)               62 non-null     object
# dtypes: float64(4), int64(2), object(4)
# memory usage: 5.3+ KB

# %%
#tikrinam ar yra tusciu reiksmiu
zuvys_kartu.isnull().sum()
# Out:
# Vandens telkinio pavadinimas      0
# Kodas                             0
# Savivaldybė                       0
# Žuvų išteklių būklės indeksasi    0
# Biomasė (kg)i                     0
# Gausumas (vnt.)i                  0
# Plėšrių žuvų gausumas (%)i        0
# Plėšrių žuvų biomasė (%)i         0
# Ešerys (Gausumas)                 0
# Karšis (Gausumas)                 0
# dtype: int64

# %%
#kadangi nera tusciu reiksmiu, tada susirasiu reiksmes su "-"
#zuvys_kartu['Ešerys (Gausumas)'] = zuvys_kartu['Ešerys (Gausumas)'].fillna('0')
 # 'Ešerys (Gausumas)',
 # 'Karšis (Gausumas)'

# %%
zuvys_kartu = zuvys_kartu.replace(['-'], '0')

# %%
zuvys_kartu.head(52)
# Out:
#       Vandens telkinio pavadinimas     Kodas          Savivaldybė  \
# index
# 1                          Aisetas  12140251       Utenos r. sav.
# 2                          Almajas  12130086    Ignalinos r. sav.
# 3                            Alnis  12130082       Molėtų r. sav.
# 4                Antakmenių ežeras  10030651        Trakų r. sav.
# 5            Antanavo HE tvenkinys  15050005    Marijampolės sav.
# 6                         Apvardai  50030211    Ignalinos r. sav.
# 7                           Arinas  12140420       Molėtų r. sav.
# 8                          Asalnai  12130004    Ignalinos r. sav.
# 9                           Asavas  12230015       Zarasų r. sav.
# 10                          Atesys  10040584      Alytaus r. sav.
# 11       Aukštadvario HE tvenkinys  10050212        Trakų r. sav.
# 12                          Aviris  10030319     Druskininkų sav.
# 13      Baltosios Ančios tvenkinys  10050030      Lazdijų r. sav.
# ...

# %%
# tur4tu buti vidutiniski ir kiti eilutes paskaiciavimai.patikrinti kodel tokie skaiciai.. descriptive statistics
zuvys_kartu.describe()
# Out:
#               Kodas  Žuvų išteklių būklės indeksasi  Biomasė (kg)i  \
# count  6.200000e+01                       62.000000      62.000000
# mean   1.839918e+07                        0.568548     149.127548
# std    1.307509e+07                        0.224812    1141.200635
# min    1.003001e+07                        0.210000       1.227000
# 25%    1.205523e+07                        0.430000       2.479000
# 50%    1.213533e+07                        0.505000       3.898000
# 75%    1.455006e+07                        0.685000       5.235000
# max    5.005000e+07                        1.000000    8990.000000
#
#        Gausumas (vnt.)i  Plėšrių žuvų gausumas (%)i  Plėšrių žuvų biomasė (%)i
# count         62.000000                   62.000000                  62.000000
# mean          70.193548                    1.718387                  10.815484
# std           38.749654                    1.235492                  10.189557
# ...

# %%
# patikrinti kiek kokiu bukles reiksmiu yra. Kai 1 yra lygu super gerai.
# Tai matosi kad 9 telkiniuose is 62?tikriausiai yra maksimalus ivertinimas. Manau mazai.
# sort tik pagal gautas reiksmes galiu naudoti.
zuvys_kartu['Žuvų išteklių būklės indeksasi'].value_counts(sort=True)
# Out:
# 1.00    9
# 0.44    3
# 0.45    3
# 0.28    2
# 0.52    2
# 0.50    2
# 0.43    2
# 0.65    2
# 0.48    2
# 0.31    2
# 0.49    2
# 0.70    2
# 0.55    2
# 0.63    2
# 0.30    2
# 0.42    2
# 0.76    1
# 0.26    1
# 0.67    1
# 0.35    1
# 0.40    1
# 0.21    1
# 0.58    1
# 0.59    1
# 0.57    1
# 0.64    1
# 0.77    1
# 0.29    1
# 0.33    1
# 0.69    1
# 0.46    1
# 0.47    1
# 0.74    1
# 0.51    1
# 0.80    1
# 0.37    1
# 0.60    1
# Name: Žuvų išteklių būklės indeksasi, dtype: int64

# %%
# ieskau maziausios ir didziausios reiksmes.
zuvys_kartu.loc[zuvys_kartu['Žuvų išteklių būklės indeksasi'].idxmax()]
# Out:
# Vandens telkinio pavadinimas      Antakmenių ežeras
# Kodas                                      10030651
# Savivaldybė                           Trakų r. sav.
# Žuvų išteklių būklės indeksasi                  1.0
# Biomasė (kg)i                                 5.435
# Gausumas (vnt.)i                                118
# Plėšrių žuvų gausumas (%)i                      1.0
# Plėšrių žuvų biomasė (%)i                       1.0
# Ešerys (Gausumas)                                 0
# Karšis (Gausumas)                                 0
# Name: 4, dtype: object

# %%
# su min ieskome kur blogiausia bendra bukle, ir koks skaicius.
# 0.21 reiskia kad bukle? bloga
zuvys_kartu.loc[zuvys_kartu['Žuvų išteklių būklės indeksasi'].idxmin()]
# Out:
# Vandens telkinio pavadinimas          Utenykštis
# Kodas                                   12130111
# Savivaldybė                       Utenos r. sav.
# Žuvų išteklių būklės indeksasi              0.21
# Biomasė (kg)i                              1.627
# Gausumas (vnt.)i                              53
# Plėšrių žuvų gausumas (%)i                   0.1
# Plėšrių žuvų biomasė (%)i                   3.78
# Ešerys (Gausumas)                              0
# Karšis (Gausumas)                              0
# Name: 51, dtype: object

# %%
# sugrupavimas pagal savivaldybes?
vietove = zuvys_kartu.groupby('Savivaldybė')

# %%
vietove

# %%
kokiu_daugiausia_vietu = vietove.count()

# %%
kokiu_daugiausia_vietu.head(24)
# Out:
#                      Vandens telkinio pavadinimas  Kodas  \
# Savivaldybė
# Akmenės r. sav.                                 1      1
# Alytaus r. sav.                                 2      2
# Anykščių r. sav.                                1      1
# Druskininkų sav.                                2      2
# Elektrėnų sav.                                  1      1
# Ignalinos r. sav.                               9      9
# Kaišiadorių r. sav.                             1      1
# Kretingos r. sav.                               1      1
# Kėdainių r. sav.                                2      2
# Lazdijų r. sav.                                 6      6
# Marijampolės sav.                               1      1
# Molėtų r. sav.                                  9      9
# Pakruojo r. sav.                                1      1
# Rokiškio r. sav.                                1      1
# Telšių r. sav.                                  3      3
# ...

# %%
#Randu, kad daugiausia ezeru, "kaip netiketa" yra Ignalinoj. net 9, 6 utenoj,trakuose ir telsiuose, svencioniu r.sav po 3. 
#kitur dar maziau. tyrimas atliktas ten tik 2 arba 1 telkinyje.
# naujas[naujas['Energy']>3]['Energy']

# neteisingai skaiciuoja kiek ezeru kokiose savivaldybese yra su puikia bukle.
kokiu_daugiausia_vietu[kokiu_daugiausia_vietu['Žuvų išteklių būklės indeksasi']>0.9]['Žuvų išteklių būklės indeksasi']
# Out:
# Savivaldybė
# Akmenės r. sav.        1
# Alytaus r. sav.        2
# Anykščių r. sav.       1
# Druskininkų sav.       2
# Elektrėnų sav.         1
# Ignalinos r. sav.      9
# Kaišiadorių r. sav.    1
# Kretingos r. sav.      1
# Kėdainių r. sav.       2
# Lazdijų r. sav.        6
# Marijampolės sav.      1
# Molėtų r. sav.         9
# Pakruojo r. sav.       1
# Rokiškio r. sav.       1
# Telšių r. sav.         3
# Trakų r. sav.          4
# Ukmergės r. sav.       2
# Utenos r. sav.         6
# Zarasų r. sav.         3
# Šalčininkų r. sav.     1
# Šiaulių r. sav.        1
# Šilalės r. sav.        1
# Švenčionių r. sav.     3
# Name: Žuvų išteklių būklės indeksasi, dtype: int64

# %%
#(zuvys_kartu['Žuvų išteklių būklės indeksasi']=='1').sum()
# Out:
# 0

# %%
#(kokiu_daugiausia_vietu['Žuvų išteklių būklės indeksasi']=='1').sum()
# Out:
# 0

# %%
#list(zuvys_kartu['Žuvų išteklių būklės indeksasi']).count('1')
# Out:
# 0

# %%
#df['column_name'].value_counts()[value]

# %%
#suskaiciuoju kiek yra indeksu lygiu 1
zuvys_kartu['Žuvų išteklių būklės indeksasi'].value_counts()[1]
# Out:
# 9

# %%
# vidurkiai_pagal = data.columns.tolist()
# megstamiausias_zanras = grupuoti.mean(numeric_only=True).idxmax()
# didziausia_reiksme = grupuoti.mean(numeric_only=True).max()
# rezultatas = pd.DataFrame([vidurkiai_pagal, megstamiausias_zanras, didziausia_reiksme], ['Kriterijus', 'Žanras', 'Viso']).transpose()

# %%
# pagaliau teisingai parodo kiek kokioje savivaldybeje yra ezeru su puikia bukle, kuri lygi vienetui.
tvarkom = zuvys_kartu.groupby(['Žuvų išteklių būklės indeksasi'])['Savivaldybė'].value_counts()[1]

# %%
tvarkom
# Out:
# Savivaldybė
# Lazdijų r. sav.      3
# Molėtų r. sav.       2
# Druskininkų sav.     1
# Ignalinos r. sav.    1
# Trakų r. sav.        1
# Utenos r. sav.       1
# Name: Savivaldybė, dtype: int64
